# %% [markdown]
# <a href="https://colab.research.google.com/github/MudadlaPranay12/Pranay_GenAI_MAY_2026/blob/main/q2_library_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_book(catalog, book_id, title, author, year):
    catalog[book_id] = (title, author, year)


def borrow_book(catalog, borrowed_books, book_id):
    if book_id in catalog:
        if book_id not in borrowed_books:
            borrowed_books.append(book_id)


def return_book(borrowed_books, book_id):
    if book_id in borrowed_books:
        borrowed_books.remove(book_id)


def register_member(members, member_id):
    members.add(member_id)


def show_available(catalog, borrowed_books):
    print("\nAvailable Books:")
    for book_id in catalog:
        if book_id not in borrowed_books:
            title, author, year = catalog[book_id]
            print(book_id, "-", title, "-", author, "-", year)


catalog = {}
borrowed_books = []
members = set()

add_book(catalog, 1, "Harry Potter", "J.K. Rowling", 1997)
add_book(catalog, 2, "The Hobbit", "Tolkien", 1937)
add_book(catalog, 3, "1984", "George Orwell", 1949)
add_book(catalog, 4, "Atomic Habits", "James Clear", 2018)

register_member(members, 101)
register_member(members, 102)
register_member(members, 103)
register_member(members, 101)

borrow_book(catalog, borrowed_books, 1)
borrow_book(catalog, borrowed_books, 2)

return_book(borrowed_books, 1)

show_available(catalog, borrowed_books)
# Out:
# Available Books:
# 1 - Harry Potter - J.K. Rowling - 1997
# 3 - 1984 - George Orwell - 1949
# 4 - Atomic Habits - James Clear - 2018
